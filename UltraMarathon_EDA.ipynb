# %%
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
# Importing libraries

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES")
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_9284\3078229781.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                       22.0           4:51:39 h                Tnfrc
# 1                       22.0           5:15:45 h   Roberto Echeverría
# 2                       22.0           5:16:44 h    Puro Trail Osorno
# 3                       22.0           5:34:13 h             Columbia
# 4                       22.0           5:54:14 h       Baguales Trail
# 5                       22.0           6:25:01 h                  NaN
# 6                       22.0           6:28:00 h        Los Patagones
# 7                       22.0           6:32:24 h       Reaktiva Chile
# 8                       22.0           6:39:08 h    Puro Trail Osorno
# 9                       22.0           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286         0.0
# 1                 9.501         1.0
# 2                 9.472         2.0
# 3                 8.976         3.0
# 4                 8.469         4.0
# 5                 7.792         5.0
# 6                 7.732         6.0
# 7                 7.645         7.0
# 8                 7.516         8.0
# 9                 7.404         9.0

# %%
df.shape
# Out:
# (4443117, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                   float64
# dtype: object

# %%
# Cleaning up data

# %%
# Showing only USA races, 50km or 50mi, 2020

# %%
df[df['Event distance/length'] == '50mi' ]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 4440369           2004  03.07.2004
# 4440370           2004  03.07.2004
# 4440371           2004  03.07.2004
# 4440372           2004  03.07.2004
# 4440373           2004  03.07.2004
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 4440369         Finger Lakes Fifties 50 Mile Run (USA)                  50mi
# 4440370         Finger Lakes Fifties 50 Mile Run (USA)                  50mi
# 4440371         Finger Lakes Fifties 50 Mile Run (USA)                  50mi
# 4440372         Finger Lakes Fifties 50 Mile Run (USA)                  50mi
# 4440373         Finger Lakes Fifties 50 Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                             9.0           9:53:05 h  *Middleville, MI
# 56                             9.0          11:09:35 h     *Waterloo, ON
# 57                             9.0          11:33:00 h    *Kitchener, ON
# 58                             9.0          11:38:17 h        *Utica, MI
# 59                             9.0          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 4440369                       14.0          11:17:18 h               NaN
# 4440370                       14.0          11:28:23 h               NaN
# 4440371                       14.0          11:54:52 h               NaN
# 4440372                       14.0          12:23:37 h               NaN
# 4440373                       14.0          12:23:37 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 4440369             USA                 1966.0              M
# 4440370             USA                 1945.0              M
# 4440371             USA                 1948.0              M
# 4440372             USA                 1953.0              M
# 4440373             USA                 1964.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141        55.0
# 56                       W40                 7.211        56.0
# 57                       M40                 6.967        57.0
# 58                       M23                 6.914        58.0
# 59                       M23                 6.738        59.0
# ...                      ...                   ...         ...
# 4440369                  M35                 7.128    707170.0
# 4440370                  M55                 7.014    693222.0
# 4440371                  M55                 6.754    146473.0
# 4440372                  M50                 6.493   1206696.0
# 4440373                  W35                 6.493   1206699.0
#
# [190263 rows x 13 columns]

# %%
# Combining 50km/50mi with isin

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']== 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...                                          ...                   ...
# 2762404               Bison Ultra-Trail 50 (POL)                  50km
# 2762405               Bison Ultra-Trail 50 (POL)                  50km
# 2762406               Bison Ultra-Trail 50 (POL)                  50km
# 2762407               Bison Ultra-Trail 50 (POL)                  50km
# 2762408               Bison Ultra-Trail 50 (POL)                  50km
#
#          Event number of finishers Athlete performance          Athlete club  \
# 2538571                       38.0           7:34:19 h                   日本隊
# 2538572                       38.0           7:43:50 h                   NaN
# 2538573                       38.0           8:04:40 h                   NaN
# 2538574                       38.0           8:30:49 h             台灣大腳ㄚ長跑協會
# 2538575                       38.0           8:34:47 h                   NaN
# ...                            ...                 ...                   ...
# 2762404                      271.0           7:36:25 h  AKS Polonia Warszawa
# 2762405                      271.0           7:36:27 h             *Warszawa
# 2762406                      271.0           7:44:18 h      Outdoor Training
# 2762407                      271.0           8:04:50 h      PH Bysewo Gdańsk
# 2762408                      271.0           8:11:43 h    *Nowe Aleksandrowo
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538571             JPN                 1965.0              M
# 2538572             AUS                 1974.0              M
# 2538573             TPE                 1976.0              M
# 2538574             TPE                 1969.0              F
# 2538575             TPE                 1964.0              M
# ...                 ...                    ...            ...
# 2762404             POL                 1981.0              F
# 2762405             POL                 1970.0              F
# 2762406             POL                 1993.0              F
# 2762407             POL                 1976.0              M
# 2762408             POL                 1961.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538571                  M50                10.627     53107.0
# 2538572                  M45                10.409      8785.0
# 2538573                  M40                 9.962      4502.0
# 2538574                  W50                 9.452     63964.0
# 2538575                  M55                 9.379      4485.0
# ...                      ...                   ...         ...
# 2762404                  W35                 6.573    860743.0
# 2762405                  W45                 6.572    860744.0
# 2762406                  W23                 6.461    860745.0
# 2762407                  M40                 6.188    798409.0
# 2762408                  M55                 6.101    860746.0
#
# [63489 rows x 13 columns]

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 2591511    USA
# 2591512    USA
# 2591513    USA
# 2591514    USA
# 2591515    USA
# Name: Event name, Length: 190, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 4443111           2004  19.06.2004
# 4443112           2004  19.06.2004
# 4443113           2004  19.06.2004
# 4443114           2004  19.06.2004
# 4443115           2004  19.06.2004
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 4443111            Rachel Carson Trail Challenge (USA)                  34mi
# 4443112            Rachel Carson Trail Challenge (USA)                  34mi
# 4443113            Rachel Carson Trail Challenge (USA)                  34mi
# 4443114            Rachel Carson Trail Challenge (USA)                  34mi
# 4443115            Rachel Carson Trail Challenge (USA)                  34mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                             9.0           9:53:05 h  *Middleville, MI
# 56                             9.0          11:09:35 h     *Waterloo, ON
# 57                             9.0          11:33:00 h    *Kitchener, ON
# 58                             9.0          11:38:17 h        *Utica, MI
# 59                             9.0          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 4443111                      311.0          13:58:01 h   *Zelienople, PA
# 4443112                      311.0          13:58:35 h   *Pittsburgh, PA
# 4443113                      311.0          14:00:25 h    *Ford City, PA
# 4443114                      311.0          14:00:35 h   *Kittanning, PA
# 4443115                      311.0          14:01:20 h   *Gettysburg, PA
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 4443111             USA                 1945.0              F
# 4443112             USA                 1971.0              M
# 4443113             USA                 1971.0              M
# 4443114             USA                 1978.0              M
# 4443115             USA                 1976.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141        55.0
# 56                       W40                 7.211        56.0
# 57                       M40                 6.967        57.0
# 58                       M23                 6.914        58.0
# 59                       M23                 6.738        59.0
# ...                      ...                   ...         ...
# 4443111                  W55                 3.918   1252250.0
# 4443112                  M23                 3.915   1252251.0
# 4443113                  M23                 3.906     35403.0
# 4443114                  M23                 3.906   1252252.0
# 4443115                  M23                 3.902   1195881.0
#
# [802339 rows x 13 columns]

# %%
# Combining all the filters together

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']== 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                                ...                   ...
# 2760957   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760958   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760959   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760960   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760961   Yankee Springs Fall Trail Run Festival (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                       20.0           3:17:55 h
# 2539946                       20.0           4:02:32 h
# 2539947                       20.0           4:07:57 h
# 2539948                       20.0           4:22:02 h
# 2539949                       20.0           4:27:34 h
# ...                            ...                 ...
# 2760957                       30.0           7:07:48 h
# 2760958                       30.0           7:27:22 h
# 2760959                       30.0           7:27:24 h
# 2760960                       30.0           7:38:30 h
# 2760961                       30.0           7:59:53 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
# ...                         ...             ...                    ...
# 2760957       *East Lansing, MI             USA                 1958.0
# 2760958      *Traverse City, MI             USA                 1977.0
# 2760959      *Traverse City, MI             USA                 1962.0
# 2760960              *Mason, MI             USA                 1981.0
# 2760961                     NaN             USA                 1980.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158     71287.0
# 2539946              M                  M35                12.369    629508.0
# 2539947              M                 MU23                12.099     64838.0
# 2539948              M                  M35                11.449    704450.0
# 2539949              M                  M40                11.212    810281.0
# ...                ...                  ...                   ...         ...
# 2760957              F                  W60                 7.013    816361.0
# 2760958              F                  W40                 6.706    326469.0
# 2760959              F                  W55                 6.705    372174.0
# 2760960              F                  W35                 6.543    860349.0
# 2760961              M                  M35                 6.252    770097.0
#
# [26090 rows x 13 columns]

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']== 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                                ...                   ...
# 2760957   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760958   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760959   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760960   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760961   Yankee Springs Fall Trail Run Festival (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                       20.0           3:17:55 h
# 2539946                       20.0           4:02:32 h
# 2539947                       20.0           4:07:57 h
# 2539948                       20.0           4:22:02 h
# 2539949                       20.0           4:27:34 h
# ...                            ...                 ...
# 2760957                       30.0           7:07:48 h
# 2760958                       30.0           7:27:22 h
# 2760959                       30.0           7:27:24 h
# 2760960                       30.0           7:38:30 h
# 2760961                       30.0           7:59:53 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
# ...                         ...             ...                    ...
# 2760957       *East Lansing, MI             USA                 1958.0
# 2760958      *Traverse City, MI             USA                 1977.0
# 2760959      *Traverse City, MI             USA                 1962.0
# 2760960              *Mason, MI             USA                 1981.0
# 2760961                     NaN             USA                 1980.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158     71287.0
# 2539946              M                  M35                12.369    629508.0
# 2539947              M                 MU23                12.099     64838.0
# 2539948              M                  M35                11.449    704450.0
# 2539949              M                  M40                11.212    810281.0
# ...                ...                  ...                   ...         ...
# 2760957              F                  W60                 7.013    816361.0
# 2760958              F                  W40                 6.706    326469.0
# 2760959              F                  W55                 6.705    372174.0
# 2760960              F                  W35                 6.543    860349.0
# 2760961              M                  M35                 6.252    770097.0
#
# [26090 rows x 13 columns]

# %%
df2.shape
# Out:
# (26090, 13)

# %%
# Removing USA from Event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_9284\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
# Cleaning up Athlete age

# %%
df2['athlete_age'] = 2020 -df2['Athlete year of birth']
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_9284\1174654226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 -df2['Athlete year of birth']

# %%
#remove h from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_9284\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                       20.0             3:17:55
# 2539946                  50km                       20.0             4:02:32
# 2539947                  50km                       20.0             4:07:57
# 2539948                  50km                       20.0             4:22:02
# 2539949                  50km                       20.0             4:27:34
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 2539945              M                  M23                15.158     71287.0
# 2539946              M                  M35                12.369    629508.0
# 2539947              M                 MU23                12.099     64838.0
# 2539948              M                  M35                11.449    704450.0
# 2539949              M                  M40                11.212    810281.0
#
#          athlete_age
# 2539945         29.0
# 2539946         39.0
# 2539947         21.0
# 2539948         37.0
# 2539949         43.0

# %%
# Drop columns:Athlete Club, Athlete Country, Athlete year of birth, Athlete Age Category

# %%
df2 = df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'], axis = 1)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                       20.0             3:17:55
# 2539946                  50km                       20.0             4:02:32
# 2539947                  50km                       20.0             4:07:57
# 2539948                  50km                       20.0             4:22:02
# 2539949                  50km                       20.0             4:27:34
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2539945              M                15.158     71287.0         29.0
# 2539946              M                12.369    629508.0         39.0
# 2539947              M                12.099     64838.0         21.0
# 2539948              M                11.449    704450.0         37.0
# 2539949              M                11.212    810281.0         43.0

# %%
# Cleaning up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2547794                  50km                       57.0             6:10:30
# 2551331                  50km                       54.0             4:46:34
# 2551336                  50km                       54.0             5:08:36
# 2551344                  50km                       54.0             5:54:04
# 2551348                  50km                       54.0             6:07:11
# ...                       ...                        ...                 ...
# 2746543                  50km                        8.0             8:31:26
# 2749869                  50mi                       27.0            11:55:05
# 2755985                  50mi                       23.0             9:03:25
# 2755994                  50mi                       23.0            10:37:00
# 2755997                  50mi                       23.0            12:30:00
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2547794              M                 8.097    811923.0          NaN
# 2551331              M                10.469    812656.0          NaN
# 2551336              M                 9.721    812657.0          NaN
# 2551344              F                 8.473    658221.0          NaN
# 2551348              M                  8.17    812660.0          NaN
# ...                ...                   ...         ...          ...
# 2746543              F                 5.866    857251.0          NaN
# 2749869              M                 6.752    857957.0          NaN
# 2755985              M                 8.885    859462.0          NaN
# 2755994              M                 7.579    398583.0          NaN
# 2755997              M                 6.437    859465.0          NaN
#
# [233 rows x 10 columns]

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (25857, 10)

# %%
# Checking for duplicates

# %%
df2[df2.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
# Reseting index

# %%
df2.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# 0                      50km                       20.0             3:17:55
# 1                      50km                       20.0             4:02:32
# 2                      50km                       20.0             4:07:57
# 3                      50km                       20.0             4:22:02
# 4                      50km                       20.0             4:27:34
# ...                     ...                        ...                 ...
# 25852                  50km                       30.0             7:07:48
# 25853                  50km                       30.0             7:27:22
# 25854                  50km                       30.0             7:27:24
# 25855                  50km                       30.0             7:38:30
# 25856                  50km                       30.0             7:59:53
#
#       Athlete gender Athlete average speed  Athlete ID  athlete_age
# 0                  M                15.158     71287.0         29.0
# 1                  M                12.369    629508.0         39.0
# 2                  M                12.099     64838.0         21.0
# 3                  M                11.449    704450.0         37.0
# 4                  M                11.212    810281.0         43.0
# ...              ...                   ...         ...          ...
# 25852              F                 7.013    816361.0         62.0
# 25853              F                 6.706    326469.0         43.0
# 25854              F                 6.705    372174.0         58.0
# 25855              F                 6.543    860349.0         39.0
# 25856              M                 6.252    770097.0         40.0
#
# [25857 rows x 10 columns]

# %%
# Fixing types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age']  = df2['athlete_age'].astype(int)
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_9284\2592927633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age']  = df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_9284\501852820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                       20.0             3:17:55
# 2539946                  50km                       20.0             4:02:32
# 2539947                  50km                       20.0             4:07:57
# 2539948                  50km                       20.0             4:22:02
# 2539949                  50km                       20.0             4:27:34
#
#         Athlete gender  Athlete average speed  Athlete ID  athlete_age
# 2539945              M                 15.158     71287.0           29
# 2539946              M                 12.369    629508.0           39
# 2539947              M                 12.099     64838.0           21
# 2539948              M                 11.449    704450.0           37
# 2539949              M                 11.212    810281.0           43

# %%
# Renaming columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers    float64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed         object
#Athlete ID                   float64
#Athlete_age                  float64

# %%
df2 = df2.rename(columns = {'Year of event':'year' ,
                            'Event dates':'race_day',
                            'Event name':'race_name',
                            'Event distance/length':'race_length',
                            'Event number of finishers':'race_number_of_finishers',
                            'Athlete performance':'athlete_performance',
                            'Athlete gender':'athlete_gender',
                            'Athlete average speed':'athlete_average_speed',
                            'Athlete ID':'athlete_id'
                           })

# %%
df2.head()
# Out:
#          year    race_day                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                      20.0             3:17:55
# 2539946        50km                      20.0             4:02:32
# 2539947        50km                      20.0             4:07:57
# 2539948        50km                      20.0             4:22:02
# 2539949        50km                      20.0             4:27:34
#
#         athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 2539945              M                 15.158     71287.0           29
# 2539946              M                 12.369    629508.0           39
# 2539947              M                 12.099     64838.0           21
# 2539948              M                 11.449    704450.0           37
# 2539949              M                 11.212    810281.0           43

# %%
# Reordering columns

# %%
df3 = df2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                      20.0     71287.0              M           29
# 2539946                      20.0    629508.0              M           39
# 2539947                      20.0     64838.0              M           21
# 2539948                      20.0    704450.0              M           37
# 2539949                      20.0    810281.0              M           43
#
#         athlete_performance  athlete_average_speed
# 2539945             3:17:55                 15.158
# 2539946             4:02:32                 12.369
# 2539947             4:07:57                 12.099
# 2539948             4:22:02                 11.449
# 2539949             4:27:34                 11.212

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length']=='50mi']['athlete_average_speed'])

# %%
sns.violinplot(data = df3,x = 'race_length', y = 'athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quart', linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x = 'athlete_age',y='athlete_average_speed',hue='athlete_gender')

# %%
# Difference in speed for the 50km,50mi male to female

# %%
df3.groupby(['race_length','athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.083011
#              M                 7.738985
# 50mi         F                 6.834371
#              M                 7.257633
# Name: athlete_average_speed, dtype: float64

# %%
# What age groups are the best in the 50mi race (20 + races minimum)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182
